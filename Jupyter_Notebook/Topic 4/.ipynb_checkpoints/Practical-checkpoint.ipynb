# %% [markdown]
# # Topic 4

# %%
# Importing relevant libraries
import pandas as pd
import numpy as np

# %% [markdown]
# ### Question 1

# %% [markdown]
# ### Question 2

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Question 4

# %% [markdown]
# ### Question 5

# %% [markdown]
# ### Question 6

# %% [markdown]
# ### Question 7

# %%
# Part A
df = pd.read_csv('graduate-employment-survey-ntu-nus-sit-smu-sutd-utf8.csv')
df.drop('year', axis = 1)
df.drop('employment_rate_overall', axis = 1)
df.drop('basic_monthly_mean', axis = 1)
df.drop('basic_monthly_median', axis = 1)
df.drop('gross_mthly_25_percentile', axis = 1)
df.drop('gross_mthly_75_percentile', axis = 1)

df[(df['university'] != 'Nanyang Technological University') & (df['university'] != 'Singapore Institute of Technology')]
# Out:
#      year                                     university  \
# 73   2013                Singapore Management University
# 74   2013                Singapore Management University
# 75   2013                Singapore Management University
# 76   2013                Singapore Management University
# 77   2013                Singapore Management University
# ..    ...                                            ...
# 284  2015                Singapore Management University
# 285  2015  Singapore University of Technology and Design
# 286  2015  Singapore University of Technology and Design
# 287  2015  Singapore University of Technology and Design
# 288  2015  Singapore University of Technology and Design
#
#                                           school  \
# 73   School of Accountancy (4-years programme) *
# 74   School of Accountancy (4-years programme) *
# 75      School of Business (4-years programme) *
# 76      School of Business (4-years programme) *
# 77     School of Economics (4-years programme) *
# ..                                           ...
# 284           School of Law (4-year programme) *
# 285                                           na
# 286                                           na
# 287                                           na
# 288                                           na
#
#                                                 degree  \
# 73                     Accountancy (4-years programme)
# 74   Accountancy (4-years programme) Cum Laude and ...
# 75             Business Management (4-years programme)
# 76   Business Management (4-years programme) Cum La...
# 77                       Economics (4-years programme)
# ..                                                 ...
# 284                            Law Cum Laude and above
# 285  Bachelor of Engineering (Engineering Product D...
# 286  Bachelor of Engineering (Engineering Systems a...
# 287  Bachelor of Engineering (Information Systems T...
# 288  Bachelor of Science (Architecture and Sustaina...
#
#     employment_rate_overall employment_rate_permanent basic_monthly_mean  \
# 73                     94.2                      93.2               3231
# 74                     95.2                      95.2               3580
# 75                     93.2                      87.3               3344
# 76                     95.9                      93.8               3825
# 77                     90.6                      88.6               3389
# ..                      ...                       ...                ...
# 284                     100                       100               5160
# 285                    92.5                      88.1               3595
# 286                    80.3                      71.8               3699
# 287                      86                      83.7               3872
# 288                      na                        na                 na
#
#     basic_monthly_median gross_monthly_mean gross_monthly_median  \
# 73                  2800               3342                 2825
# 74                  2900               3634                 3000
# 75                  3000               3520                 3200
# 76                  3500               3975                 3580
# 77                  3200               3513                 3339
# ..                   ...                ...                  ...
# 284                 4766               5313                 5000
# 285                 3618               3565                 3600
# 286                 3450               3763                 3500
# 287                 3700               3952                 3950
# 288                   na                 na                   na
#
#     gross_mthly_25_percentile gross_mthly_75_percentile
# 73                       2700                      3430
# 74                       2700                      3750
# 75                       2800                      3750
# 76                       3000                      4100
# 77                       3000                      3800
# ..                        ...                       ...
# 284                      4500                      5995
# 285                      3400                      3800
# 286                      3190                      4100
# 287                      3338                      4450
# 288                        na                        na
#
# [64 rows x 12 columns]

# %% [markdown]
# ### Question 8

# %%
# Part A
mydf = pd.read_excel('singstats_maritalstatus.xlsx', index_col='Variables', na_values="-")
variables = pd.isnull(mydf)

# print("***** Use isnull to see if a column or row contains data *****")
# variables

# %%
# Part B
mydf = pd.read_excel('singstats_maritalstatus.xlsx', index_col='Variables', na_values = "-")
# print("***** First 10 rows of original data *****")
# mydf.head(10)

# print("***** Remaining dataset after dropping columns with missing data *****")
mydf2 = mydf.dropna(axis = 1)
# mydf2.head()

# %%
# Part C
mydf = pd.read_csv('hdbresaleindex_missing.csv', index_col = "quarter")

df_missing = pd.isnull(mydf)
df_missing = mydf[pd.isnull(mydf['index'])]

mydf1 = mydf.fillna(50)
mydf2 = mydf.fillna(method='pad')
mydf3 = mydf.fillna(method='bfill')
mydf4 = mydf.fillna(mydf.mean())

# %% [markdown]
# ### Question 9

# %%
df1 = pd.read_csv('mergedataset1s.csv')
df2 = pd.read_csv('mergedataset2s.csv')

# Left get priortized and information get retains
df = pd.merge(df1, df2, how="left",on='customerid')
# Right get priortized and information get retains
df = pd.merge(df1, df2, how='right', on='customerid')
# Only join when they have record on both table
df = pd.merge(df1, df2, how="inner", on='customerid')

# ADVANCED (NOT NEEDED)
df = df1[df1.customerid.isin(df2.customerid)]

# %%
df_m = pd.read_csv('merge_students-male.csv')
df_f = pd.read_csv('merge_students-female.csv')
df_test = pd.read_csv('merge_testscores.csv')

df_students = pd.concat([df_m, df_f])
df_merged = pd.merge(df_students, df_test, how="inner", on='studentid')
df_merged.sort_values('test score', ascending = False)
# Out:
#      studentid LastName FirstName Gender  test score
# 496    1500039      Lim    Sophie      F          99
# 332    1500689       Ho    Daniel      M          99
# 580    1500224      Loh     Tania      F          99
# 167    1500317      Low   Zechary      M          99
# 952    1500905     Choo     Susan      F          99
# ..         ...      ...       ...    ...         ...
# 655    1500379      Lee      Xena      F          20
# 120    1500221      Low    Oliver      M          20
# 421    1500879      Soh   Leonard      M          20
# 741    1500517      Lee     Emily      F          20
# 778    1500582       Ho    Regina      F          20
#
# [1007 rows x 5 columns]
